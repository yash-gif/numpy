# %%
import numpy as np

# %%
arr_1D=np.array([1,2,3,4])
print(arr_1D)
# Out:
# [1 2 3 4]

# %%
type(arr_1D)
# Out:
# numpy.ndarray

# %%
arr_1D.ndim
# Out:
# 1

# %%
arr_2D=np.array([[1,2,3,4],
               [2,3,45,5],
               [6,7,8,9]])

# %%
type(arr_2D)
# Out:
# numpy.ndarray

# %%
arr_2D.ndim
# Out:
# 2

# %%
print(arr_2D)
# Out:
# [[ 1  2  3  4]
#  [ 2  3 45  5]
#  [ 6  7  8  9]]

# %%
arr_2D.size
# Out:
# 12

# %%
arr_2D.shape
# Out:
# (3, 4)

# %%
#(row,coloum)

# %%
arr_2D.dtype
# Out:
# dtype('int32')
